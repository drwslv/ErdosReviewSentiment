# %% [markdown]
# ## Summary stats
#
# Trained on NVidia RTX 3070 with 8GM VRAM
#
# Datasets can be found here: https://drive.google.com/drive/folders/1ek-ITB2fmp1KtOBfQHJXKwFpQ-eqvUzU?usp=drive_link
#
# Roberta
# - train duration: 9 hr 21 min 4.8 sec
# - accuracy: 88.21%
# - f1: 0.86976
#
# Bert
# - train duration: 20 hr 4 min 22.9 sec
# - accuracy: 83.00%
# - f1: 0.78945
#
# Bidirectional LSTM
# - runtime: 1 hr 53 min 28.2 sec
# - accuracy: 85.43%,
# - f1 F1 0.86750

# %%
import pandas as pd
df = pd.read_csv('./data/midwest/big-test-sampled.csv')

# %%
df.head()
# Out:
#    rating                                               text  \
# 0       5  love the 200 happyhour 2pm till 5pm thn again ...
# 1       4  the food is decent and the cheese curds are aw...
# 2       4                                       very helpful
# 3       5  we had the best dinner here great open spot th...
# 4       5                                         my new fav
#
#                  type  pnn                        bert - probs  \
# 0  Takeout Restaurant    2  [0.02318591 0.03596894 0.94084525]
# 1          Restaurant    2  [0.00246261 0.01222768 0.98530966]
# 2          Restaurant    2  [0.04512969 0.08537012 0.86950016]
# 3    Asian restaurant    2  [0.00457231 0.0160854  0.97934234]
# 4          Restaurant    2  [0.03288918 0.03597173 0.9311391 ]
#
#                                   roberta - probs  \
# 0     [5.0048920e-04 4.9842149e-03 9.9451524e-01]
# 1              [0.00142059 0.03283421 0.9657452 ]
# 2              [0.00179214 0.02205463 0.97615325]
# ...
