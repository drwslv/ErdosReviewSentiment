# %% [markdown]
# ## Summary stats
#
# All models trained on NVidia RTX 3070 with 8GM VRAM
#
# Datasets can be found on the github page (https://github.com/drwslv/ErdosReviewSentiment), except for the big dataset which can be found at (https://drive.google.com/drive/folders/1ek-ITB2fmp1KtOBfQHJXKwFpQ-eqvUzU?usp=drive_link)

# %%
import pandas as pd

# %% [markdown]
# ## All regions
#
# Size:
#
# - train
# - val
# - test
#
# Mean rating:
#
# Distribution:
#
# LSTM
#
# - train duration: 4 hrs 8 min
# - accuracy (test): 98.11%
# - f1 (test): 0.98132

# %%
df_regions = pd.read_csv('./data/

# %% [markdown]
# ## Big dataset (all types)
#
# Size:
# - train 1,600,000 samples
# - val 400,000 samples
# - test 400,000 samples
#
# Mean rating: 4.140 (train)
#
# Distribution: 5 (56.5%), 4 (21.1%), 3 (9.87%), 2 (7.50%), 1 (5.04%)
#
# Roberta
# - train duration: 9.5 hrs
# - accuracy: 88.21%
# - f1: 0.86976
#
# Bert-base
# - train duration: 20 hrs
# - accuracy: 83.00%
# - f1: 0.78945
#
# Bidirectional LSTM
# - train duration: 2 hrs
# - accuracy: 85.43%
# - f1: 0.86750

# %%
df_all = pd.read_csv('./data/midwest/big-test-sampled.csv')

# %%
# Do some analysis on what different models predict -- could be interesting
df_all.head()
# Out:
#    rating                                               text  \
# 0       5  love the 200 happyhour 2pm till 5pm thn again ...
# 1       4  the food is decent and the cheese curds are aw...
# 2       4                                       very helpful
# 3       5  we had the best dinner here great open spot th...
# 4       5                                         my new fav
#
#                  type  pnn  bert - neg  bert - mixed  bert - pos  bert - pred  \
# 0  Takeout Restaurant    2    0.023186      0.035969    0.940845            2
# 1          Restaurant    2    0.002463      0.012228    0.985310            2
# 2          Restaurant    2    0.045130      0.085370    0.869500            2
# 3    Asian restaurant    2    0.004572      0.016085    0.979342            2
# 4          Restaurant    2    0.032889      0.035972    0.931139            2
#
#    lstm - neg  lstm - mixed  lstm - pos  lstm - pred  roberta - neg  \
# 0    0.005154      0.053283    0.941562            2       0.000500
# 1    0.010283      0.586117    0.403600            1       0.001421
# 2    0.010875      0.147983    0.841142            2       0.001792
# 3    0.000389      0.003394    0.996217            2       0.000106
# 4    0.053597      0.258251    0.688152            2       0.001298
#
#    roberta - mixed  roberta - pos  roberta - pred
# 0         0.004984       0.994515               2
# 1         0.032834       0.965745               2
# 2         0.022055       0.976153               2
# 3         0.001357       0.998536               2
# 4         0.007771       0.990931               2

# %% [markdown]
# ## Thai restaurants
# Sizes
# - train 66,494 samples
# - val 16,577 samples
# - test 7,272 samples
#
# Mean rating: 4.398 (train)
#
# Distribution: 5 (65.8%), 4 (20.0%), 3 (6.69%), 2 (4.27%), 1 (3.33%)
#
# Roberta
# - train duration: 37 min
# - accuracy: 91.79%
# - f1: >0.9
#
# Bert-base
# - train duration: 3 hrs
# - accuracy: 86.67%
# - f1: 0.81714
#
# Bidirectional LSTM
# - train duration: 15 minutes
# - accuracy: 91.05%
# - f1: >0.9
#
#
# ** Interestingly, bert model learned to *never* predict neutral/mixed
#
# ** Something strange with the test df is causing errors in writing the probabilities

# %%
df_thai = pd.read_csv('./data/thai-test.csv')
df_thai.head()
# Out:
#    rating                                               text  pnn  lstm-neg  \
# 0       5         Highly recommended! Good food and service.    2  0.000652
# 1       5  Excellence. Every time. My only regret is the ...    2  0.000957
# 2       5  Over a hour wait on a Friday night and still 5...    2  0.000805
# 3       5  A little hole in the wall I found! It's my go ...    2  0.001335
# 4       5                     Halal chicken is good on menu.    2  0.001496
#
#    lstm-mixed  lstm-pos  lstm-pred  bert-neg  bert-mixed  bert-pos  bert-pred  \
# 0    0.003544  0.995804          2  0.022161    0.034850  0.942989          2
# 1    0.008405  0.990637          2  0.048450    0.027053  0.924497          2
# 2    0.020384  0.978811          2  0.047122    0.043983  0.908895          2
# 3    0.612893  0.385772          1  0.201603    0.154658  0.643739          2
# 4    0.004327  0.994177          2  0.009803    0.028463  0.961734          2
#
#    roberta-neg  roberta-mixed  roberta-pos  roberta-pred
# 0     0.000143       0.001649     0.998208             2
# 1     0.076064       0.128215     0.795721             2
# 2     0.000941       0.005765     0.993294             2
# 3     0.275129       0.265585     0.459286             2
# 4     0.002927       0.075450     0.921623             2

# %% [markdown]
# ## Vegetarian restaurants
# Sizes:
# - train 480,135 samples
# - val 96,027 samples
# - test 58,655 samples (989.5kB)
#
# Mean rating: 3.802 (train)
#
# Distribution: 5 (45.7%), 4 (21.0%), 3 (13.5%), 2 (12.5%), 1 (7.22%)
#
# Roberta
# - train duration: 2 hr 25 min
# - accuracy: 83.69%
# - f1: 0.82592
#
# Bert-base
# - train duration: ~ 12 hrs
# - accuracy: 77.48%
# - f1: 0.73062
#
# Bidirectional LSTM
# - train duration: 3 hr 23 min
# - accuracy: 88.32%
# - f1: 0.88769

# %%
df_veg = pd.read_csv('./data/veg-test.csv')
df_veg.head()
# Out:
#    rating                                               text  pnn  lstm-neg  \
# 0       5       Really good food. I would recommend the BLT.    2  0.000191
# 1       5                                            Love it    2  0.001472
# 2       5            Their food is always fresh and amazing.    2  0.000018
# 3       5  We eat here about once every two weeks and the...    2  0.000098
# 4       5                                              Great    2  0.014054
#
#    lstm-mixed  lstm-pos  lstm-pred  roberta-neg  roberta-mixed  roberta-pos  \
# 0    0.065677  0.934132          2     0.000591       0.008005     0.991403
# 1    0.034975  0.963553          2     0.003498       0.009959     0.986543
# 2    0.000607  0.999375          2     0.000255       0.004217     0.995528
# 3    0.000555  0.999347          2     0.017518       0.083187     0.899295
# 4    0.089928  0.896018          2     0.008188       0.036346     0.955466
#
#    roberta-pred  bert-neg  bert-mixed  bert-pos  bert-pred
# 0             2  0.036378    0.089517  0.874104          2
# 1             2  0.015457    0.017589  0.966954          2
# 2             2  0.003684    0.012754  0.983563          2
# 3             2  0.153344    0.198355  0.648301          2
# 4             2  0.051032    0.074190  0.874779          2

# %%
df_veg[df_veg['lstm-pred'] != df_veg['roberta-pred']].sample(20)
# Out:
#        rating                                               text  pnn  \
# 39204       4  Good ambiance..food is hygienic but tastes ave...    2
# 36823       4  Service was great, Gail was on top of everythi...    2
# 46698       3         Missing item,  had to go inside to get it.    1
# 40780       3                       Ordering is easier by choice    1
# 43876       3                     Deleted the App. Doesn't work.    1
# 33727       4  food is great. the restaurant however is not t...    2
# 12758       5  I was really shocked by how good this was. It ...    2
# 40271       3  Shouldn't come up under "authentic".  It's Tex...    1
# 15572       5  I said it before but I'll say it again rice ha...    2
# 36622       4                Burrito was good. Was pretty quick.    2
# 38515       4                                          Fast food    2
# 31514       4           Pretty decent, cool take on sushi rolls.    2
# 40335       3                               Messed up the order.    1
# 41618       3       Decent food. They're open late which is nice    1
# 45853       3  It took a very long time to get just a burrito...    1
# 55137       2  Now you have to use a Kiosk to order... My God...    0
# 30212       4  Food good, just wish they stil sold mexican pi...    2
# 39609       3  Sad when you order a double crunch wrap and it...    1
# 40500       3  Not the cleanest taco bell but the service was...    1
# 57082       2  (Translated by Google) Alful\n\n(Original)\nAlful    0
#
#        lstm-neg  lstm-mixed  lstm-pos  lstm-pred  \
# 39204  0.002174    0.970895  0.026931          1
# 36823  0.017220    0.064379  0.918401          2
# 46698  0.025730    0.950828  0.023442          1
# 40780  0.001316    0.979651  0.019034          1
# 43876  0.002364    0.995229  0.002407          1
# 33727  0.003697    0.035671  0.960632          2
# 12758  0.008996    0.953055  0.037949          1
# 40271  0.000794    0.899700  0.099506          1
# 15572  0.449899    0.483312  0.066789          1
# 36622  0.000930    0.784725  0.214346          1
# 38515  0.111177    0.705002  0.183821          1
# 31514  0.001223    0.614522  0.384256          1
# 40335  0.019957    0.961951  0.018092          1
# 41618  0.007071    0.883558  0.109371          1
# 45853  0.001609    0.995080  0.003311          1
# 55137  0.009333    0.212462  0.778205          2
# 30212  0.000895    0.864831  0.134273          1
# 39609  0.002787    0.971103  0.026111          1
# 40500  0.608051    0.306464  0.085484          0
# 57082  0.461395    0.269294  0.269311          0
#
#                                               clean-text  roberta-neg  \
# 39204  good ambiancefood is hygienic but tastes avera...     0.061745
# 36823  service was great gail was on top of everythin...     0.137809
# 46698           missing item  had to go inside to get it     0.711072
# 40780                       ordering is easier by choice     0.040907
# 43876                        deleted the app doesnt work     0.889053
# 33727  food is great the restaurant however is not th...     0.074438
# 12758  i was really shocked by how good this was it w...     0.132980
# 40271       shouldnt come up under authentic  its texmex     0.688561
# 15572  i said it before but ill say it again rice has...     0.772058
# 36622                  burrito was good was pretty quick     0.001476
# 38515                                          fast food     0.021294
# 31514             pretty decent cool take on sushi rolls     0.004707
# 40335                                messed up the order     0.649057
# 41618         decent food theyre open late which is nice     0.006335
# 45853  it took a very long time to get just a burrito...     0.672385
# 55137  now you have to use a kiosk to order my god th...     0.903276
# 30212   food good just wish they stil sold mexican pizza     0.021858
# 39609  sad when you order a double crunch wrap and it...     0.529794
# 40500  not the cleanest taco bell but the service was...     0.016041
# 57082                              alful  original alful     0.061416
#
#        roberta-mixed  roberta-pos  roberta-pred
# 39204       0.455215     0.483039             2
# 36823       0.431464     0.430727             1
# 46698       0.215077     0.073850             0
# 40780       0.355741     0.603352             2
# 43876       0.092455     0.018492             0
# 33727       0.629343     0.296219             1
# 12758       0.235578     0.631441             2
# 40271       0.195022     0.116417             0
# 15572       0.174053     0.053889             0
# 36622       0.090498     0.908026             2
# 38515       0.178665     0.800041             2
# 31514       0.244319     0.750974             2
# 40335       0.308268     0.042676             0
# 41618       0.108473     0.885191             2
# 45853       0.249672     0.077942             0
# 55137       0.077141     0.019583             0
# 30212       0.366678     0.611464             2
# 39609       0.357373     0.112833             0
# 40500       0.400930     0.583029             2
# 57082       0.217787     0.720796             2
